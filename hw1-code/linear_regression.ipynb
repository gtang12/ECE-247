# %% [markdown]
# ## Linear regression workbook
#
# This workbook will walk you through a linear regression example. It will provide familiarity with Jupyter Notebook and Python.  Please print (to pdf) a completed version of this workbook for submission with HW #1.
#
# ECE C147/C247 Winter Quarter 2022, Prof. J.C. Kao, TAs Y. Li, P. Lu, T. Monsoor, T. wang

# %%
import numpy as np 
import matplotlib.pyplot as plt

#allows matlab plots to be generated in line
# %matplotlib inline

# %% [markdown]
# ### Data generation
#
# For any example, we first have to generate some appropriate data to use. The following cell generates data according to the model: $y = x - 2x^2 + x^3 + \epsilon$

# %%
np.random.seed(0)  # Sets the random seed.
num_train = 200     # Number of training data points

# Generate the training data
x = np.random.uniform(low=0, high=1, size=(num_train,))
y = x - 2*x**2 + x**3 + np.random.normal(loc=0, scale=0.03, size=(num_train,))
f = plt.figure()
ax = f.gca()
ax.plot(x, y, '.')
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
plt.show()

# %% [markdown]
# ### QUESTIONS:
#
# Write your answers in the markdown cell below this one:
#
# (1) What is the generating distribution of $x$?
#
# (2) What is the distribution of the additive noise $\epsilon$?

# %% [markdown]
# ### ANSWERS:
#
# (1) $x$ has a uniform distribution over the interval $[0,1)$.
#
# (2) $\epsilon$ has a normal distribution with zero mean and standard deviation of 0.03.

# %% [markdown]
# ### Fitting data to the model (5 points)
#
# Here, we'll do linear regression to fit the parameters of a model $y = ax + b$.

# %%
# xhat = (x, 1)
xhat = np.vstack((x, np.ones_like(x)))

# ==================== #
# START YOUR CODE HERE #
# ==================== #
# GOAL: create a variable theta; theta is a numpy array whose elements are [a, b]

theta = np.linalg.inv(xhat.dot(xhat.T)).dot(xhat.dot(y)) # please modify this line

# ================== #
# END YOUR CODE HERE #
# ================== #

# %%
# Plot the data and your model fit.
f = plt.figure()
ax = f.gca()
ax.plot(x, y, '.')
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')

# Plot the regression line
xs = np.linspace(min(x), max(x),50)
xs = np.vstack((xs, np.ones_like(xs)))
plt.plot(xs[0,:], theta.dot(xs))
plt.show()

# %% [markdown]
# ### QUESTIONS
#
# (1) Does the linear model under- or overfit the data?
#
# (2) How to change the model to improve the fitting?

# %% [markdown]
# ### ANSWERS
#
# (1) The model underfits the data, since linear regression does not capture the original cubic function, and the plot shows large errors between the data and the model.
#
# (2) A model with greater capacity can be chosen, such as a polynomial model of degree 2 or 3.

# %% [markdown]
# ### Fitting data to the model (10 points)
#
# Here, we'll now do regression to polynomial models of orders 1 to 5.  Note, the order 1 model is the linear model you prior fit.

# %%
N = 5
xhats = []
thetas = []

# ==================== #
# START YOUR CODE HERE #
# ==================== #

# GOAL: create a variable thetas.
# thetas is a list, where theta[i] are the model parameters for the polynomial fit of order i+1.
#   i.e., thetas[0] is equivalent to theta above.
#   i.e., thetas[1] should be a length 3 np.array with the coefficients of the x^2, x, and 1 respectively.
#   ... etc.

for i in np.arange(N):
    if i == 0:
        xhat = np.vstack((x, np.ones_like(x)))
    else:
        xhat = np.vstack((xhat[-2]**(i+1), xhat))
    xhats.append(xhat)
    theta = np.linalg.inv(xhat.dot(xhat.T)).dot(xhat.dot(y))
    thetas.append(theta)

# ================== #
# END YOUR CODE HERE #
# ================== #

# %%
# Plot the data
f = plt.figure(figsize=(8,6))
ax = f.gca()
ax.plot(x, y, '.')
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')

# Plot the regression lines
plot_xs = []
for i in np.arange(N):
    if i == 0:
        plot_x = np.vstack((np.linspace(min(x), max(x),50), np.ones(50)))
    else:
        plot_x = np.vstack((plot_x[-2]**(i+1), plot_x))                              
    plot_xs.append(plot_x)

for i in np.arange(N):
    ax.plot(plot_xs[i][-2,:], thetas[i].dot(plot_xs[i]))

labels = ['data']
[labels.append('n={}'.format(i+1)) for i in np.arange(N)]
bbox_to_anchor=(1.3, 1)
lgd = ax.legend(labels, bbox_to_anchor=bbox_to_anchor)

# %% [markdown]
# ### Calculating the training error (10 points)
#
# Here, we'll now calculate the training error of polynomial models of orders 1 to 5:
#
# $L(\theta) = \frac{1}{2}\sum_{j}(\hat{y}_j - y_j)^2$

# %%
training_errors = []

# ==================== #
# START YOUR CODE HERE #
# ==================== #

# GOAL: create a variable training_errors, a list of 5 elements,
# where training_errors[i] are the training loss for the polynomial fit of order i+1.
for i in np.arange(N):
    training_error = 0.5*np.sum((np.dot(thetas[i],xhats[i]) - y)**2)
    training_errors.append(training_error)

# ================== #
# END YOUR CODE HERE #
# ================== #

print ('Training errors are: \n', training_errors)
# Out:
# Training errors are:
#  [0.2379961088362701, 0.10924922209268531, 0.08169603801105374, 0.08165353735296982, 0.08161479195525298]

# %% [markdown]
# ### QUESTIONS
#
# (1) Which polynomial model has the best training error?
#
# (2) Why is this expected?

# %% [markdown]
# ### ANSWERS
#
# (1) The 5th order polynomial has the best training error of about 0.081615.
#
# (2) This is expected because increasing the order of the polynomial provides additional degrees of freedom to fit the model to the training data.

# %% [markdown]
# ### Generating new samples and validation error (5 points)
#
# Here, we'll now generate new samples and calculate the validation error of polynomial models of orders 1 to 5.

# %%
x = np.random.uniform(low=1, high=2, size=(num_train,))
y = x - 2*x**2 + x**3 + np.random.normal(loc=0, scale=0.03, size=(num_train,))
f = plt.figure()
ax = f.gca()
ax.plot(x, y, '.')
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
plt.show()

# %%
xhats = []
for i in np.arange(N):
    if i == 0:
        xhat = np.vstack((x, np.ones_like(x)))
        plot_x = np.vstack((np.linspace(min(x), max(x),50), np.ones(50)))
    else:
        xhat = np.vstack((x**(i+1), xhat))
        plot_x = np.vstack((plot_x[-2]**(i+1), plot_x))
                              
    xhats.append(xhat)

# %%
# Plot the data
f = plt.figure()
ax = f.gca()
ax.plot(x, y, '.')
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')

# Plot the regression lines
plot_xs = []
for i in np.arange(N):
    if i == 0:
        plot_x = np.vstack((np.linspace(min(x), max(x),50), np.ones(50)))
    else:
        plot_x = np.vstack((plot_x[-2]**(i+1), plot_x))                              
    plot_xs.append(plot_x)

for i in np.arange(N):
    ax.plot(plot_xs[i][-2,:], thetas[i].dot(plot_xs[i]))

labels = ['data']
[labels.append('n={}'.format(i+1)) for i in np.arange(N)]
bbox_to_anchor=(1.3, 1)
lgd = ax.legend(labels, bbox_to_anchor=bbox_to_anchor)

# %%
validation_errors = []

# ==================== #
# START YOUR CODE HERE #
# ==================== #

# GOAL: create a variable validation_errors, a list of 5 elements,
# where validation_errors[i] are the validation loss for the polynomial fit of order i+1.
for i in np.arange(N):
    validation_error = 0.5*np.sum((np.dot(thetas[i],xhats[i]) - y)**2)
    validation_errors.append(validation_error)

# ================== #
# END YOUR CODE HERE #
# ================== #

print ('Validation errors are: \n', validation_errors)
# Out:
# Validation errors are:
#  [76.99016367401433, 203.73253090771198, 3.1520054583156663, 0.9956642534278806, 195.75036659155884]

# %% [markdown]
# ### QUESTIONS
#
# (1) Which polynomial model has the best validation error?
#
# (2) Why does the order-5 polynomial model not generalize well?

# %% [markdown]
# ### ANSWERS
#
# (1) The 4th order polynomial model has the best validation error of about 0.9957.
#
# (2) The 5th order polynomial model does not generalize well because the greater number of parameters allowed it to overfit on the training data, and the model was optimized specifically for $x$ in $[0,1)$.
