# %% [markdown]
# # ECE C147/247 HW4 Q3: Dropout
#
# In this notebook, you will implement dropout.  Then we will ask you to train a network with batchnorm and dropout, and acheive over 55% accuracy on CIFAR-10.
#
# `utils` has built a solid API for building these modular frameworks and training them, and we will use their very well implemented framework as opposed to "reinventing the wheel."  This includes using their Solver, various utility functions, and their layer structure.  This also includes `nndl.fc_net`, `nndl.layers`, and `nndl.layer_utils`.

# %%
## Import and setups

import time
import numpy as np
import matplotlib.pyplot as plt
from nndl.fc_net import *
from nndl.layers import *
from utils.data_utils import get_CIFAR10_data
from utils.gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from utils.solver import Solver

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
  """ returns relative error """
  return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %%
# Load the (preprocessed) CIFAR10 data.

data = get_CIFAR10_data()
for k in data.keys():
  print('{}: {} '.format(k, data[k].shape))
# Out:
# X_train: (49000, 3, 32, 32)
# y_train: (49000,)
# X_val: (1000, 3, 32, 32)
# y_val: (1000,)
# X_test: (1000, 3, 32, 32)
# y_test: (1000,)

# %% [markdown]
# ## Dropout forward pass
#
# Implement the training and test time dropout forward pass, `dropout_forward`, in `nndl/layers.py`. After that, test your implementation by running the following cell.

# %%
x = np.random.randn(500, 500) + 10

for p in [0.3, 0.6, 0.75]:
  out, _ = dropout_forward(x, {'mode': 'train', 'p': p})
  out_test, _ = dropout_forward(x, {'mode': 'test', 'p': p})

  print('Running tests with p = ', p)
  print('Mean of input: ', x.mean())
  print('Mean of train-time output: ', out.mean())
  print('Mean of test-time output: ', out_test.mean())
  print('Fraction of train-time output set to zero: ', (out == 0).mean())
  print('Fraction of test-time output set to zero: ', (out_test == 0).mean())
# Out:
# Running tests with p =  0.3
# Mean of input:  10.001493381747778
# Mean of train-time output:  10.001579417426006
# Mean of test-time output:  10.001493381747778
# Fraction of train-time output set to zero:  0.299988
# Fraction of test-time output set to zero:  0.0
# Running tests with p =  0.6
# Mean of input:  10.001493381747778
# Mean of train-time output:  10.044955655185339
# Mean of test-time output:  10.001493381747778
# Fraction of train-time output set to zero:  0.59826
# Fraction of test-time output set to zero:  0.0
# Running tests with p =  0.75
# Mean of input:  10.001493381747778
# Mean of train-time output:  10.026089587950741
# Mean of test-time output:  10.001493381747778
# Fraction of train-time output set to zero:  0.749388
# Fraction of test-time output set to zero:  0.0

# %% [markdown]
# ## Dropout backward pass
#
# Implement the backward pass, `dropout_backward`, in `nndl/layers.py`.  After that, test your gradients by running the following cell:

# %%
x = np.random.randn(10, 10) + 10
dout = np.random.randn(*x.shape)

dropout_param = {'mode': 'train', 'p': 0.8, 'seed': 123}
out, cache = dropout_forward(x, dropout_param)
dx = dropout_backward(dout, cache)
dx_num = eval_numerical_gradient_array(lambda xx: dropout_forward(xx, dropout_param)[0], x, dout)

print('dx relative error: ', rel_error(dx, dx_num))
# Out:
# dx relative error:  1.892903597711978e-11

# %% [markdown]
# ## Implement a fully connected neural network with dropout layers
#
# Modify the `FullyConnectedNet()` class in `nndl/fc_net.py` to incorporate dropout.  A dropout layer should be incorporated after every ReLU layer.  Concretely, there shouldn't be a dropout at the output layer since there is no ReLU at the output layer. You will need to modify the class in the following areas:
#
# (1) In the forward pass, you will need to incorporate a dropout layer after every relu layer.
#
# (2) In the backward pass, you will need to incorporate a dropout backward pass layer.
#
# Check your implementation by running the following code.  Our W1 gradient relative error is on the order of 1e-6 (the largest of all the relative errors).

# %%
N, D, H1, H2, C = 2, 15, 20, 30, 10
X = np.random.randn(N, D)
y = np.random.randint(C, size=(N,))

for dropout in [0, 0.25, 0.5]:
  print('Running check with dropout = ', dropout)
  model = FullyConnectedNet([H1, H2], input_dim=D, num_classes=C,
                            weight_scale=5e-2, dtype=np.float64,
                            dropout=dropout, seed=123)

  loss, grads = model.loss(X, y)
  print('Initial loss: ', loss)

  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = eval_numerical_gradient(f, model.params[name], verbose=False, h=1e-5)
    print('{} relative error: {}'.format(name, rel_error(grad_num, grads[name])))
  print('\n')
# Out:
# Running check with dropout =  0
# Initial loss:  2.303043161170242
# W1 relative error: 4.795196913586914e-07
# W2 relative error: 1.9717710552624993e-07
# W3 relative error: 1.5587099391417707e-07
# b1 relative error: 2.0336164373878067e-08
# b2 relative error: 1.686315567518667e-09
# b3 relative error: 1.1144421861081857e-10
#
#
# Running check with dropout =  0.25
# Initial loss:  2.3121038288812437
# W1 relative error: 1.955407335718557e-07
# W2 relative error: 5.534386227801714e-07
# W3 relative error: 5.931379043397433e-06
# b1 relative error: 3.013100438431333e-09
# b2 relative error: 1.1772388958095999e-08
# b3 relative error: 9.191146118924487e-11
#
#
# Running check with dropout =  0.5
# Initial loss:  2.304242617164796
# W1 relative error: 1.2078835425125906e-07
# W2 relative error: 2.4541280899580378e-08
# W3 relative error: 8.057428016665365e-07
# b1 relative error: 2.2762561911407695e-08
# b2 relative error: 6.836026635756729e-10
# b3 relative error: 1.2833211144563337e-10

# %% [markdown]
# ## Dropout as a regularizer
#
# In class, we claimed that dropout acts as a regularizer by effectively bagging.  To check this, we will train two small networks, one with dropout and one without dropout.

# %%
# Train two identical nets, one with dropout and one without

num_train = 500
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

solvers = {}
dropout_choices = [0, 0.6]
for dropout in dropout_choices:
  model = FullyConnectedNet([100, 100, 100], dropout=dropout)

  solver = Solver(model, small_data,
                  num_epochs=25, batch_size=100,
                  update_rule='adam',
                  optim_config={
                    'learning_rate': 5e-4,
                  },
                  verbose=True, print_every=100)
  solver.train()
  solvers[dropout] = solver
# Out:
# (Iteration 1 / 125) loss: 2.301575
# (Epoch 0 / 25) train acc: 0.236000; val_acc: 0.169000
# (Epoch 1 / 25) train acc: 0.212000; val_acc: 0.162000
# (Epoch 2 / 25) train acc: 0.266000; val_acc: 0.227000
# (Epoch 3 / 25) train acc: 0.302000; val_acc: 0.246000
# (Epoch 4 / 25) train acc: 0.366000; val_acc: 0.287000
# (Epoch 5 / 25) train acc: 0.428000; val_acc: 0.300000
# (Epoch 6 / 25) train acc: 0.466000; val_acc: 0.310000
# (Epoch 7 / 25) train acc: 0.540000; val_acc: 0.329000
# (Epoch 8 / 25) train acc: 0.594000; val_acc: 0.319000
# (Epoch 9 / 25) train acc: 0.636000; val_acc: 0.311000
# (Epoch 10 / 25) train acc: 0.640000; val_acc: 0.322000
# (Epoch 11 / 25) train acc: 0.694000; val_acc: 0.303000
# (Epoch 12 / 25) train acc: 0.764000; val_acc: 0.318000
# (Epoch 13 / 25) train acc: 0.780000; val_acc: 0.326000
# (Epoch 14 / 25) train acc: 0.820000; val_acc: 0.326000
# (Epoch 15 / 25) train acc: 0.860000; val_acc: 0.301000
# (Epoch 16 / 25) train acc: 0.872000; val_acc: 0.294000
# (Epoch 17 / 25) train acc: 0.930000; val_acc: 0.310000
# (Epoch 18 / 25) train acc: 0.936000; val_acc: 0.290000
# (Epoch 19 / 25) train acc: 0.954000; val_acc: 0.290000
# (Epoch 20 / 25) train acc: 0.946000; val_acc: 0.284000
# (Iteration 101 / 125) loss: 0.234130
# (Epoch 21 / 25) train acc: 0.964000; val_acc: 0.298000
# (Epoch 22 / 25) train acc: 0.970000; val_acc: 0.293000
# (Epoch 23 / 25) train acc: 0.984000; val_acc: 0.304000
# (Epoch 24 / 25) train acc: 0.994000; val_acc: 0.279000
# (Epoch 25 / 25) train acc: 0.994000; val_acc: 0.294000
# (Iteration 1 / 125) loss: 2.301265
# (Epoch 0 / 25) train acc: 0.110000; val_acc: 0.095000
# (Epoch 1 / 25) train acc: 0.168000; val_acc: 0.156000
# (Epoch 2 / 25) train acc: 0.206000; val_acc: 0.205000
# (Epoch 3 / 25) train acc: 0.244000; val_acc: 0.236000
# (Epoch 4 / 25) train acc: 0.242000; val_acc: 0.240000
# (Epoch 5 / 25) train acc: 0.272000; val_acc: 0.247000
# (Epoch 6 / 25) train acc: 0.274000; val_acc: 0.254000
# (Epoch 7 / 25) train acc: 0.288000; val_acc: 0.256000
# (Epoch 8 / 25) train acc: 0.294000; val_acc: 0.241000
# (Epoch 9 / 25) train acc: 0.302000; val_acc: 0.237000
# (Epoch 10 / 25) train acc: 0.330000; val_acc: 0.268000
# (Epoch 11 / 25) train acc: 0.342000; val_acc: 0.256000
# (Epoch 12 / 25) train acc: 0.406000; val_acc: 0.276000
# (Epoch 13 / 25) train acc: 0.434000; val_acc: 0.289000
# (Epoch 14 / 25) train acc: 0.422000; val_acc: 0.290000
# (Epoch 15 / 25) train acc: 0.416000; val_acc: 0.288000
# (Epoch 16 / 25) train acc: 0.414000; val_acc: 0.290000
# (Epoch 17 / 25) train acc: 0.424000; val_acc: 0.300000
# (Epoch 18 / 25) train acc: 0.462000; val_acc: 0.305000
# (Epoch 19 / 25) train acc: 0.464000; val_acc: 0.302000
# (Epoch 20 / 25) train acc: 0.488000; val_acc: 0.310000
# (Iteration 101 / 125) loss: 1.536692
# (Epoch 21 / 25) train acc: 0.472000; val_acc: 0.282000
# (Epoch 22 / 25) train acc: 0.490000; val_acc: 0.324000
# (Epoch 23 / 25) train acc: 0.522000; val_acc: 0.309000
# (Epoch 24 / 25) train acc: 0.506000; val_acc: 0.302000
# (Epoch 25 / 25) train acc: 0.534000; val_acc: 0.303000

# %%
# Plot train and validation accuracies of the two models

train_accs = []
val_accs = []
for dropout in dropout_choices:
  solver = solvers[dropout]
  train_accs.append(solver.train_acc_history[-1])
  val_accs.append(solver.val_acc_history[-1])

plt.subplot(3, 1, 1)
for dropout in dropout_choices:
  plt.plot(solvers[dropout].train_acc_history, '-o', label='%.2f dropout' % dropout)
plt.title('Train accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(ncol=2, loc='lower right')
  
plt.subplot(3, 1, 2)
for dropout in dropout_choices:
  plt.plot(solvers[dropout].val_acc_history, '-o', label='%.2f dropout' % dropout)
plt.title('Val accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(ncol=2, loc='lower right')

plt.gcf().set_size_inches(15, 15)
plt.show()

# %% [markdown]
# ## Question
#
# Based off the results of this experiment, is dropout performing regularization?  Explain your answer.

# %% [markdown]
# ## Answer:
#
# Dropout is performing regularization because it improves validation accuracy. Without dropout, the training accuracy reaches nearly 1.0 but has low validation accuracy, suggesting that the model is overfitting. The training error with 0.60 dropout is low compared to the training error with no dropout, but dropout achieves slightly higher validation accuracy which is closer to the training accuracy, so it improves the model's ability to generalize to new data.

# %% [markdown]
# ## Final part of the assignment
#
# Get over 55% validation accuracy on CIFAR-10 by using the layers you have implemented.  You will be graded according to the following equation:
#
# `min(floor((X - 32%)) / 28%, 1)`
#
# where if you get 60% or higher validation accuracy, you get full points.

# %%
# ================================================================ #
# YOUR CODE HERE:
#   Implement a FC-net that achieves at least 55% validation accuracy
#   on CIFAR-10.
# ================================================================ #

model = FullyConnectedNet([500, 500, 500, 500, 500], reg=0.1, dropout=0.3, use_batchnorm=True)

solver = Solver(model, data,
                  num_epochs=100, batch_size=100,
                  update_rule='adam',
                  optim_config={
                    'learning_rate': 1e-4,
                  },
                  verbose=True, print_every=100)
solver.train()

# ================================================================ #
# END YOUR CODE HERE
# ================================================================ #
# Out:
# (Iteration 1 / 49000) loss: 15.028948
# (Epoch 0 / 100) train acc: 0.115000; val_acc: 0.091000
# (Iteration 101 / 49000) loss: 8.548667
# (Iteration 201 / 49000) loss: 5.534624
# (Iteration 301 / 49000) loss: 4.078068
# (Iteration 401 / 49000) loss: 3.233668
# (Epoch 1 / 100) train acc: 0.435000; val_acc: 0.459000
# (Iteration 501 / 49000) loss: 2.678006
# (Iteration 601 / 49000) loss: 2.516704
# (Iteration 701 / 49000) loss: 2.347057
# (Iteration 801 / 49000) loss: 2.322517
# (Iteration 901 / 49000) loss: 2.024315
# (Epoch 2 / 100) train acc: 0.463000; val_acc: 0.456000
# (Iteration 1001 / 49000) loss: 1.933691
# (Iteration 1101 / 49000) loss: 2.274947
# (Iteration 1201 / 49000) loss: 2.104155
# (Iteration 1301 / 49000) loss: 2.023319
# (Iteration 1401 / 49000) loss: 1.901117
# (Epoch 3 / 100) train acc: 0.462000; val_acc: 0.464000
# (Iteration 1501 / 49000) loss: 1.816517
# (Iteration 1601 / 49000) loss: 2.013837
# (Iteration 1701 / 49000) loss: 1.893080
# (Iteration 1801 / 49000) loss: 2.007207
# (Iteration 1901 / 49000) loss: 2.135378
# (Epoch 4 / 100) train acc: 0.451000; val_acc: 0.477000
# (Iteration 2001 / 49000) loss: 1.871868
# (Iteration 2101 / 49000) loss: 1.788051
# (Iteration 2201 / 49000) loss: 1.645793
# (Iteration 2301 / 49000) loss: 1.887592
# (Iteration 2401 / 49000) loss: 1.983035
# (Epoch 5 / 100) train acc: 0.493000; val_acc: 0.462000
# (Iteration 2501 / 49000) loss: 1.796497
# (Iteration 2601 / 49000) loss: 1.886231
# (Iteration 2701 / 49000) loss: 1.816434
# (Iteration 2801 / 49000) loss: 1.894124
# (Iteration 2901 / 49000) loss: 1.895259
# (Epoch 6 / 100) train acc: 0.440000; val_acc: 0.475000
# (Iteration 3001 / 49000) loss: 1.993659
# (Iteration 3101 / 49000) loss: 1.971222
# (Iteration 3201 / 49000) loss: 1.935994
# (Iteration 3301 / 49000) loss: 1.772658
# (Iteration 3401 / 49000) loss: 2.066478
# (Epoch 7 / 100) train acc: 0.489000; val_acc: 0.473000
# (Iteration 3501 / 49000) loss: 2.064262
# (Iteration 3601 / 49000) loss: 2.092042
# (Iteration 3701 / 49000) loss: 1.989013
# (Iteration 3801 / 49000) loss: 2.051005
# (Iteration 3901 / 49000) loss: 1.961055
# (Epoch 8 / 100) train acc: 0.467000; val_acc: 0.476000
# (Iteration 4001 / 49000) loss: 1.856273
# (Iteration 4101 / 49000) loss: 1.942688
# (Iteration 4201 / 49000) loss: 2.105008
# (Iteration 4301 / 49000) loss: 1.884448
# (Iteration 4401 / 49000) loss: 1.951686
# (Epoch 9 / 100) train acc: 0.472000; val_acc: 0.495000
# (Iteration 4501 / 49000) loss: 1.842808
# (Iteration 4601 / 49000) loss: 2.022915
# (Iteration 4701 / 49000) loss: 1.862288
# (Iteration 4801 / 49000) loss: 1.837214
# (Epoch 10 / 100) train acc: 0.503000; val_acc: 0.466000
# (Iteration 4901 / 49000) loss: 1.863110
# (Iteration 5001 / 49000) loss: 1.825474
# (Iteration 5101 / 49000) loss: 1.858658
# (Iteration 5201 / 49000) loss: 1.924010
# (Iteration 5301 / 49000) loss: 1.816286
# (Epoch 11 / 100) train acc: 0.498000; val_acc: 0.476000
# (Iteration 5401 / 49000) loss: 1.919750
# (Iteration 5501 / 49000) loss: 1.886745
# (Iteration 5601 / 49000) loss: 1.734667
# (Iteration 5701 / 49000) loss: 1.997476
# (Iteration 5801 / 49000) loss: 1.852604
# (Epoch 12 / 100) train acc: 0.532000; val_acc: 0.485000
# (Iteration 5901 / 49000) loss: 1.898328
# (Iteration 6001 / 49000) loss: 2.122056
# (Iteration 6101 / 49000) loss: 2.031682
# (Iteration 6201 / 49000) loss: 1.760251
# (Iteration 6301 / 49000) loss: 1.913086
# (Epoch 13 / 100) train acc: 0.472000; val_acc: 0.491000
# (Iteration 6401 / 49000) loss: 1.898750
# (Iteration 6501 / 49000) loss: 1.841547
# (Iteration 6601 / 49000) loss: 1.949320
# (Iteration 6701 / 49000) loss: 1.928222
# (Iteration 6801 / 49000) loss: 2.118948
# (Epoch 14 / 100) train acc: 0.483000; val_acc: 0.481000
# (Iteration 6901 / 49000) loss: 1.844515
# (Iteration 7001 / 49000) loss: 1.798997
# (Iteration 7101 / 49000) loss: 2.056109
# (Iteration 7201 / 49000) loss: 2.099214
# (Iteration 7301 / 49000) loss: 1.844507
# (Epoch 15 / 100) train acc: 0.462000; val_acc: 0.473000
# (Iteration 7401 / 49000) loss: 1.850061
# (Iteration 7501 / 49000) loss: 2.017950
# (Iteration 7601 / 49000) loss: 1.905904
# (Iteration 7701 / 49000) loss: 1.860710
# (Iteration 7801 / 49000) loss: 1.924706
# (Epoch 16 / 100) train acc: 0.499000; val_acc: 0.488000
# (Iteration 7901 / 49000) loss: 1.901835
# (Iteration 8001 / 49000) loss: 1.849748
# (Iteration 8101 / 49000) loss: 1.808507
# (Iteration 8201 / 49000) loss: 2.069551
# (Iteration 8301 / 49000) loss: 1.954271
# (Epoch 17 / 100) train acc: 0.477000; val_acc: 0.462000
# (Iteration 8401 / 49000) loss: 1.864824
# (Iteration 8501 / 49000) loss: 2.026965
# (Iteration 8601 / 49000) loss: 1.896916
# (Iteration 8701 / 49000) loss: 1.895267
# (Iteration 8801 / 49000) loss: 1.872347
# (Epoch 18 / 100) train acc: 0.501000; val_acc: 0.485000
# (Iteration 8901 / 49000) loss: 1.756907
# (Iteration 9001 / 49000) loss: 1.752159
# (Iteration 9101 / 49000) loss: 1.962780
# (Iteration 9201 / 49000) loss: 1.933629
# (Iteration 9301 / 49000) loss: 1.920987
# (Epoch 19 / 100) train acc: 0.481000; val_acc: 0.472000
# (Iteration 9401 / 49000) loss: 1.818962
# (Iteration 9501 / 49000) loss: 1.766035
# (Iteration 9601 / 49000) loss: 1.767178
# (Iteration 9701 / 49000) loss: 1.882017
# (Epoch 20 / 100) train acc: 0.464000; val_acc: 0.496000
# (Iteration 9801 / 49000) loss: 1.881975
# (Iteration 9901 / 49000) loss: 1.851943
# (Iteration 10001 / 49000) loss: 1.610409
# (Iteration 10101 / 49000) loss: 1.844227
# (Iteration 10201 / 49000) loss: 2.018571
# (Epoch 21 / 100) train acc: 0.489000; val_acc: 0.485000
# (Iteration 10301 / 49000) loss: 1.703761
# (Iteration 10401 / 49000) loss: 1.828363
# (Iteration 10501 / 49000) loss: 1.853421
# (Iteration 10601 / 49000) loss: 1.881814
# (Iteration 10701 / 49000) loss: 1.788806
# (Epoch 22 / 100) train acc: 0.471000; val_acc: 0.460000
# (Iteration 10801 / 49000) loss: 1.929326
# (Iteration 10901 / 49000) loss: 1.815805
# (Iteration 11001 / 49000) loss: 1.819876
# (Iteration 11101 / 49000) loss: 1.855335
# (Iteration 11201 / 49000) loss: 1.701458
# (Epoch 23 / 100) train acc: 0.484000; val_acc: 0.501000
# (Iteration 11301 / 49000) loss: 1.863472
# (Iteration 11401 / 49000) loss: 1.807785
# (Iteration 11501 / 49000) loss: 1.920574
# (Iteration 11601 / 49000) loss: 1.871569
# (Iteration 11701 / 49000) loss: 1.663301
# (Epoch 24 / 100) train acc: 0.495000; val_acc: 0.467000
# (Iteration 11801 / 49000) loss: 1.819194
# (Iteration 11901 / 49000) loss: 1.818299
# (Iteration 12001 / 49000) loss: 1.855098
# (Iteration 12101 / 49000) loss: 1.935776
# (Iteration 12201 / 49000) loss: 1.807883
# (Epoch 25 / 100) train acc: 0.452000; val_acc: 0.494000
# (Iteration 12301 / 49000) loss: 1.901847
# (Iteration 12401 / 49000) loss: 1.810431
# (Iteration 12501 / 49000) loss: 1.686514
# (Iteration 12601 / 49000) loss: 1.866219
# (Iteration 12701 / 49000) loss: 1.878785
# (Epoch 26 / 100) train acc: 0.503000; val_acc: 0.501000
# (Iteration 12801 / 49000) loss: 1.947165
# (Iteration 12901 / 49000) loss: 2.015293
# (Iteration 13001 / 49000) loss: 1.923129
# (Iteration 13101 / 49000) loss: 1.864046
# (Iteration 13201 / 49000) loss: 1.779584
# (Epoch 27 / 100) train acc: 0.517000; val_acc: 0.485000
# (Iteration 13301 / 49000) loss: 1.878886
# (Iteration 13401 / 49000) loss: 1.754688
# (Iteration 13501 / 49000) loss: 1.922505
# (Iteration 13601 / 49000) loss: 1.776071
# (Iteration 13701 / 49000) loss: 1.761965
# (Epoch 28 / 100) train acc: 0.496000; val_acc: 0.496000
# (Iteration 13801 / 49000) loss: 1.855115
# (Iteration 13901 / 49000) loss: 1.846766
# (Iteration 14001 / 49000) loss: 1.917599
# (Iteration 14101 / 49000) loss: 1.961745
# (Iteration 14201 / 49000) loss: 1.974073
# (Epoch 29 / 100) train acc: 0.495000; val_acc: 0.486000
# (Iteration 14301 / 49000) loss: 1.921565
# (Iteration 14401 / 49000) loss: 2.023479
# (Iteration 14501 / 49000) loss: 1.765217
# (Iteration 14601 / 49000) loss: 1.811815
# (Epoch 30 / 100) train acc: 0.491000; val_acc: 0.502000
# (Iteration 14701 / 49000) loss: 1.833869
# (Iteration 14801 / 49000) loss: 1.749074
# (Iteration 14901 / 49000) loss: 1.887198
# (Iteration 15001 / 49000) loss: 1.975371
# (Iteration 15101 / 49000) loss: 1.727513
# (Epoch 31 / 100) train acc: 0.484000; val_acc: 0.503000
# (Iteration 15201 / 49000) loss: 1.833924
# (Iteration 15301 / 49000) loss: 1.864091
# (Iteration 15401 / 49000) loss: 1.683854
# (Iteration 15501 / 49000) loss: 2.077081
# (Iteration 15601 / 49000) loss: 1.800593
# (Epoch 32 / 100) train acc: 0.487000; val_acc: 0.472000
# (Iteration 15701 / 49000) loss: 1.807242
# (Iteration 15801 / 49000) loss: 1.827054
# (Iteration 15901 / 49000) loss: 1.944137
# (Iteration 16001 / 49000) loss: 1.825254
# (Iteration 16101 / 49000) loss: 1.720081
# (Epoch 33 / 100) train acc: 0.473000; val_acc: 0.482000
# (Iteration 16201 / 49000) loss: 1.971190
# (Iteration 16301 / 49000) loss: 1.751507
# (Iteration 16401 / 49000) loss: 1.673868
# (Iteration 16501 / 49000) loss: 1.688614
# (Iteration 16601 / 49000) loss: 1.813204
# (Epoch 34 / 100) train acc: 0.502000; val_acc: 0.500000
# (Iteration 16701 / 49000) loss: 2.070835
# (Iteration 16801 / 49000) loss: 1.837396
# (Iteration 16901 / 49000) loss: 1.903969
# (Iteration 17001 / 49000) loss: 2.068371
# (Iteration 17101 / 49000) loss: 1.879173
# (Epoch 35 / 100) train acc: 0.499000; val_acc: 0.455000
# (Iteration 17201 / 49000) loss: 1.798775
# (Iteration 17301 / 49000) loss: 1.847488
# (Iteration 17401 / 49000) loss: 1.750445
# (Iteration 17501 / 49000) loss: 2.052393
# (Iteration 17601 / 49000) loss: 2.121879
# (Epoch 36 / 100) train acc: 0.511000; val_acc: 0.507000
# (Iteration 17701 / 49000) loss: 1.862422
# (Iteration 17801 / 49000) loss: 2.045801
# (Iteration 17901 / 49000) loss: 1.785842
# (Iteration 18001 / 49000) loss: 1.839250
# (Iteration 18101 / 49000) loss: 1.832672
# (Epoch 37 / 100) train acc: 0.474000; val_acc: 0.474000
# (Iteration 18201 / 49000) loss: 1.918998
# (Iteration 18301 / 49000) loss: 2.002636
# (Iteration 18401 / 49000) loss: 1.781068
# (Iteration 18501 / 49000) loss: 1.937220
# (Iteration 18601 / 49000) loss: 1.817374
# (Epoch 38 / 100) train acc: 0.498000; val_acc: 0.495000
# (Iteration 18701 / 49000) loss: 1.979358
# (Iteration 18801 / 49000) loss: 1.748496
# (Iteration 18901 / 49000) loss: 1.702142
# (Iteration 19001 / 49000) loss: 1.964629
# (Iteration 19101 / 49000) loss: 1.898532
# (Epoch 39 / 100) train acc: 0.500000; val_acc: 0.479000
# (Iteration 19201 / 49000) loss: 1.971794
# (Iteration 19301 / 49000) loss: 1.799686
# (Iteration 19401 / 49000) loss: 1.753362
# (Iteration 19501 / 49000) loss: 1.964588
# (Epoch 40 / 100) train acc: 0.500000; val_acc: 0.513000
# (Iteration 19601 / 49000) loss: 1.922498
# (Iteration 19701 / 49000) loss: 1.827059
# (Iteration 19801 / 49000) loss: 1.786699
# (Iteration 19901 / 49000) loss: 1.646423
# (Iteration 20001 / 49000) loss: 2.056274
# (Epoch 41 / 100) train acc: 0.497000; val_acc: 0.501000
# (Iteration 20101 / 49000) loss: 1.804003
# (Iteration 20201 / 49000) loss: 1.909847
# (Iteration 20301 / 49000) loss: 1.758659
# (Iteration 20401 / 49000) loss: 1.776167
# (Iteration 20501 / 49000) loss: 1.940722
# (Epoch 42 / 100) train acc: 0.534000; val_acc: 0.486000
# (Iteration 20601 / 49000) loss: 1.868157
# (Iteration 20701 / 49000) loss: 1.894385
# (Iteration 20801 / 49000) loss: 1.743522
# (Iteration 20901 / 49000) loss: 1.904732
# (Iteration 21001 / 49000) loss: 1.830263
# (Epoch 43 / 100) train acc: 0.493000; val_acc: 0.489000
# (Iteration 21101 / 49000) loss: 1.774987
# (Iteration 21201 / 49000) loss: 1.806313
# (Iteration 21301 / 49000) loss: 1.827727
# (Iteration 21401 / 49000) loss: 1.923800
# (Iteration 21501 / 49000) loss: 1.959744
# (Epoch 44 / 100) train acc: 0.511000; val_acc: 0.503000
# (Iteration 21601 / 49000) loss: 1.889117
# (Iteration 21701 / 49000) loss: 1.899842
# (Iteration 21801 / 49000) loss: 1.989452
# (Iteration 21901 / 49000) loss: 1.928066
# (Iteration 22001 / 49000) loss: 1.990194
# (Epoch 45 / 100) train acc: 0.514000; val_acc: 0.501000
# (Iteration 22101 / 49000) loss: 1.723631
# (Iteration 22201 / 49000) loss: 2.063926
# (Iteration 22301 / 49000) loss: 1.862718
# (Iteration 22401 / 49000) loss: 1.830172
# (Iteration 22501 / 49000) loss: 1.939176
# (Epoch 46 / 100) train acc: 0.502000; val_acc: 0.477000
# (Iteration 22601 / 49000) loss: 1.680119
# (Iteration 22701 / 49000) loss: 1.972806
# (Iteration 22801 / 49000) loss: 1.773537
# (Iteration 22901 / 49000) loss: 1.889350
# (Iteration 23001 / 49000) loss: 1.832018
# (Epoch 47 / 100) train acc: 0.520000; val_acc: 0.504000
# (Iteration 23101 / 49000) loss: 1.804049
# (Iteration 23201 / 49000) loss: 1.962525
# (Iteration 23301 / 49000) loss: 1.720935
# (Iteration 23401 / 49000) loss: 1.861319
# (Iteration 23501 / 49000) loss: 1.848445
# (Epoch 48 / 100) train acc: 0.503000; val_acc: 0.500000
# (Iteration 23601 / 49000) loss: 1.807486
# (Iteration 23701 / 49000) loss: 1.721921
# (Iteration 23801 / 49000) loss: 1.854968
# (Iteration 23901 / 49000) loss: 1.777535
# (Iteration 24001 / 49000) loss: 1.827542
# (Epoch 49 / 100) train acc: 0.515000; val_acc: 0.490000
# (Iteration 24101 / 49000) loss: 1.856238
# (Iteration 24201 / 49000) loss: 1.958292
# (Iteration 24301 / 49000) loss: 1.909220
# (Iteration 24401 / 49000) loss: 1.942760
# (Epoch 50 / 100) train acc: 0.497000; val_acc: 0.508000
# (Iteration 24501 / 49000) loss: 1.886262
# (Iteration 24601 / 49000) loss: 1.792394
# (Iteration 24701 / 49000) loss: 1.824578
# (Iteration 24801 / 49000) loss: 1.898601
# (Iteration 24901 / 49000) loss: 2.035760
# (Epoch 51 / 100) train acc: 0.507000; val_acc: 0.502000
# (Iteration 25001 / 49000) loss: 1.920813
# (Iteration 25101 / 49000) loss: 1.939388
# (Iteration 25201 / 49000) loss: 1.738720
# (Iteration 25301 / 49000) loss: 2.111848
# (Iteration 25401 / 49000) loss: 1.806905
# (Epoch 52 / 100) train acc: 0.529000; val_acc: 0.493000
# (Iteration 25501 / 49000) loss: 1.955111
# (Iteration 25601 / 49000) loss: 1.791623
# (Iteration 25701 / 49000) loss: 1.900634
# (Iteration 25801 / 49000) loss: 2.015763
# (Iteration 25901 / 49000) loss: 1.989480
# (Epoch 53 / 100) train acc: 0.510000; val_acc: 0.498000
# (Iteration 26001 / 49000) loss: 1.731129
# (Iteration 26101 / 49000) loss: 1.825211
# (Iteration 26201 / 49000) loss: 1.891620
# (Iteration 26301 / 49000) loss: 1.897885
# (Iteration 26401 / 49000) loss: 1.809130
# (Epoch 54 / 100) train acc: 0.484000; val_acc: 0.485000
# (Iteration 26501 / 49000) loss: 1.965119
# (Iteration 26601 / 49000) loss: 1.867779
# (Iteration 26701 / 49000) loss: 1.765409
# (Iteration 26801 / 49000) loss: 1.804610
# (Iteration 26901 / 49000) loss: 1.718345
# (Epoch 55 / 100) train acc: 0.499000; val_acc: 0.511000
# (Iteration 27001 / 49000) loss: 1.828075
# (Iteration 27101 / 49000) loss: 1.989284
# (Iteration 27201 / 49000) loss: 1.881028
# (Iteration 27301 / 49000) loss: 1.825763
# (Iteration 27401 / 49000) loss: 1.989515
# (Epoch 56 / 100) train acc: 0.517000; val_acc: 0.505000
# (Iteration 27501 / 49000) loss: 1.976278
# (Iteration 27601 / 49000) loss: 1.682174
# (Iteration 27701 / 49000) loss: 1.738326
# (Iteration 27801 / 49000) loss: 1.865973
# (Iteration 27901 / 49000) loss: 1.960220
# (Epoch 57 / 100) train acc: 0.531000; val_acc: 0.498000
# (Iteration 28001 / 49000) loss: 1.754518
# (Iteration 28101 / 49000) loss: 1.736151
# (Iteration 28201 / 49000) loss: 1.776241
# (Iteration 28301 / 49000) loss: 1.893177
# (Iteration 28401 / 49000) loss: 1.952565
# (Epoch 58 / 100) train acc: 0.522000; val_acc: 0.496000
# (Iteration 28501 / 49000) loss: 2.014629
# (Iteration 28601 / 49000) loss: 1.830972
# (Iteration 28701 / 49000) loss: 1.823292
# (Iteration 28801 / 49000) loss: 1.780692
# (Iteration 28901 / 49000) loss: 1.688906
# (Epoch 59 / 100) train acc: 0.525000; val_acc: 0.509000
# (Iteration 29001 / 49000) loss: 1.765209
# (Iteration 29101 / 49000) loss: 1.947395
# (Iteration 29201 / 49000) loss: 1.755929
# (Iteration 29301 / 49000) loss: 2.054894
# (Epoch 60 / 100) train acc: 0.505000; val_acc: 0.488000
# (Iteration 29401 / 49000) loss: 1.651814
# (Iteration 29501 / 49000) loss: 2.009939
# (Iteration 29601 / 49000) loss: 1.798731
# (Iteration 29701 / 49000) loss: 2.024388
# (Iteration 29801 / 49000) loss: 1.853494
# (Epoch 61 / 100) train acc: 0.517000; val_acc: 0.511000
# (Iteration 29901 / 49000) loss: 1.713170
# (Iteration 30001 / 49000) loss: 1.908123
# (Iteration 30101 / 49000) loss: 1.601774
# (Iteration 30201 / 49000) loss: 1.708777
# (Iteration 30301 / 49000) loss: 1.891748
# (Epoch 62 / 100) train acc: 0.502000; val_acc: 0.473000
# (Iteration 30401 / 49000) loss: 1.762304
# (Iteration 30501 / 49000) loss: 1.754367
# (Iteration 30601 / 49000) loss: 1.776304
# (Iteration 30701 / 49000) loss: 1.668721
# (Iteration 30801 / 49000) loss: 1.820821
# (Epoch 63 / 100) train acc: 0.528000; val_acc: 0.503000
# (Iteration 30901 / 49000) loss: 1.855063
# (Iteration 31001 / 49000) loss: 1.809035
# (Iteration 31101 / 49000) loss: 1.960074
# (Iteration 31201 / 49000) loss: 1.998517
# (Iteration 31301 / 49000) loss: 1.969889
# (Epoch 64 / 100) train acc: 0.513000; val_acc: 0.489000
# (Iteration 31401 / 49000) loss: 1.917950
# (Iteration 31501 / 49000) loss: 1.720637
# (Iteration 31601 / 49000) loss: 1.845463
# (Iteration 31701 / 49000) loss: 1.949906
# (Iteration 31801 / 49000) loss: 1.848096
# (Epoch 65 / 100) train acc: 0.522000; val_acc: 0.510000
# (Iteration 31901 / 49000) loss: 1.691912
# (Iteration 32001 / 49000) loss: 1.733701
# (Iteration 32101 / 49000) loss: 1.715764
# (Iteration 32201 / 49000) loss: 1.982515
# (Iteration 32301 / 49000) loss: 1.883192
# (Epoch 66 / 100) train acc: 0.506000; val_acc: 0.491000
# (Iteration 32401 / 49000) loss: 1.826140
# (Iteration 32501 / 49000) loss: 1.887479
# (Iteration 32601 / 49000) loss: 2.002645
# (Iteration 32701 / 49000) loss: 1.949633
# (Iteration 32801 / 49000) loss: 2.030148
# (Epoch 67 / 100) train acc: 0.495000; val_acc: 0.507000
# (Iteration 32901 / 49000) loss: 1.609004
# (Iteration 33001 / 49000) loss: 1.857717
# (Iteration 33101 / 49000) loss: 1.787588
# (Iteration 33201 / 49000) loss: 1.864601
# (Iteration 33301 / 49000) loss: 1.888549
# (Epoch 68 / 100) train acc: 0.519000; val_acc: 0.500000
# (Iteration 33401 / 49000) loss: 1.909203
# (Iteration 33501 / 49000) loss: 1.592334
# (Iteration 33601 / 49000) loss: 1.942747
# (Iteration 33701 / 49000) loss: 1.727772
# (Iteration 33801 / 49000) loss: 1.724114
# (Epoch 69 / 100) train acc: 0.524000; val_acc: 0.492000
# (Iteration 33901 / 49000) loss: 1.776891
# (Iteration 34001 / 49000) loss: 1.868624
# (Iteration 34101 / 49000) loss: 2.084289
# (Iteration 34201 / 49000) loss: 1.772076
# (Epoch 70 / 100) train acc: 0.491000; val_acc: 0.483000
# (Iteration 34301 / 49000) loss: 1.754492
# (Iteration 34401 / 49000) loss: 1.882006
# (Iteration 34501 / 49000) loss: 1.771593
# (Iteration 34601 / 49000) loss: 1.723983
# (Iteration 34701 / 49000) loss: 1.825868
# (Epoch 71 / 100) train acc: 0.513000; val_acc: 0.511000
# (Iteration 34801 / 49000) loss: 2.178425
# (Iteration 34901 / 49000) loss: 1.917777
# (Iteration 35001 / 49000) loss: 1.885994
# (Iteration 35101 / 49000) loss: 1.933844
# (Iteration 35201 / 49000) loss: 1.887404
# (Epoch 72 / 100) train acc: 0.512000; val_acc: 0.494000
# (Iteration 35301 / 49000) loss: 1.913906
# (Iteration 35401 / 49000) loss: 1.973819
# (Iteration 35501 / 49000) loss: 1.881132
# (Iteration 35601 / 49000) loss: 1.869191
# (Iteration 35701 / 49000) loss: 1.779933
# (Epoch 73 / 100) train acc: 0.506000; val_acc: 0.505000
# (Iteration 35801 / 49000) loss: 1.792794
# (Iteration 35901 / 49000) loss: 1.778207
# (Iteration 36001 / 49000) loss: 1.862027
# (Iteration 36101 / 49000) loss: 1.819315
# (Iteration 36201 / 49000) loss: 1.967060
# (Epoch 74 / 100) train acc: 0.536000; val_acc: 0.503000
# (Iteration 36301 / 49000) loss: 1.862513
# (Iteration 36401 / 49000) loss: 1.870730
# (Iteration 36501 / 49000) loss: 1.761950
# (Iteration 36601 / 49000) loss: 1.899086
# (Iteration 36701 / 49000) loss: 1.899588
# (Epoch 75 / 100) train acc: 0.495000; val_acc: 0.505000
# (Iteration 36801 / 49000) loss: 1.807398
# (Iteration 36901 / 49000) loss: 1.768431
# (Iteration 37001 / 49000) loss: 1.801364
# (Iteration 37101 / 49000) loss: 1.817897
# (Iteration 37201 / 49000) loss: 1.716502
# (Epoch 76 / 100) train acc: 0.506000; val_acc: 0.498000
# (Iteration 37301 / 49000) loss: 1.682041
# (Iteration 37401 / 49000) loss: 2.146312
# (Iteration 37501 / 49000) loss: 1.660079
# (Iteration 37601 / 49000) loss: 1.991961
# (Iteration 37701 / 49000) loss: 1.833270
# (Epoch 77 / 100) train acc: 0.504000; val_acc: 0.511000
# (Iteration 37801 / 49000) loss: 1.694400
# (Iteration 37901 / 49000) loss: 1.925755
# (Iteration 38001 / 49000) loss: 1.865983
# (Iteration 38101 / 49000) loss: 1.829592
# (Iteration 38201 / 49000) loss: 1.678601
# (Epoch 78 / 100) train acc: 0.488000; val_acc: 0.488000
# (Iteration 38301 / 49000) loss: 1.977569
# (Iteration 38401 / 49000) loss: 1.810358
# (Iteration 38501 / 49000) loss: 1.769015
# (Iteration 38601 / 49000) loss: 1.958505
# (Iteration 38701 / 49000) loss: 2.026368
# (Epoch 79 / 100) train acc: 0.495000; val_acc: 0.492000
# (Iteration 38801 / 49000) loss: 1.874370
# (Iteration 38901 / 49000) loss: 1.772644
# (Iteration 39001 / 49000) loss: 1.724861
# (Iteration 39101 / 49000) loss: 1.738078
# (Epoch 80 / 100) train acc: 0.503000; val_acc: 0.488000
# (Iteration 39201 / 49000) loss: 1.839286
# (Iteration 39301 / 49000) loss: 1.792472
# (Iteration 39401 / 49000) loss: 1.840067
# (Iteration 39501 / 49000) loss: 1.872544
# (Iteration 39601 / 49000) loss: 1.933564
# (Epoch 81 / 100) train acc: 0.528000; val_acc: 0.510000
# (Iteration 39701 / 49000) loss: 1.830874
# (Iteration 39801 / 49000) loss: 1.980036
# (Iteration 39901 / 49000) loss: 1.812206
# (Iteration 40001 / 49000) loss: 1.842945
# (Iteration 40101 / 49000) loss: 1.878012
# (Epoch 82 / 100) train acc: 0.486000; val_acc: 0.512000
# (Iteration 40201 / 49000) loss: 1.860776
# (Iteration 40301 / 49000) loss: 1.913223
# (Iteration 40401 / 49000) loss: 1.916587
# (Iteration 40501 / 49000) loss: 1.915710
# (Iteration 40601 / 49000) loss: 2.012348
# (Epoch 83 / 100) train acc: 0.506000; val_acc: 0.504000
# (Iteration 40701 / 49000) loss: 1.772776
# (Iteration 40801 / 49000) loss: 1.819122
# (Iteration 40901 / 49000) loss: 2.013341
# (Iteration 41001 / 49000) loss: 1.853554
# (Iteration 41101 / 49000) loss: 1.888000
# (Epoch 84 / 100) train acc: 0.519000; val_acc: 0.497000
# (Iteration 41201 / 49000) loss: 1.837233
# (Iteration 41301 / 49000) loss: 1.660805
# (Iteration 41401 / 49000) loss: 1.825223
# (Iteration 41501 / 49000) loss: 2.009652
# (Iteration 41601 / 49000) loss: 1.870842
# (Epoch 85 / 100) train acc: 0.490000; val_acc: 0.482000
# (Iteration 41701 / 49000) loss: 1.715559
# (Iteration 41801 / 49000) loss: 1.622763
# (Iteration 41901 / 49000) loss: 2.034105
# (Iteration 42001 / 49000) loss: 1.825436
# (Iteration 42101 / 49000) loss: 1.871180
# (Epoch 86 / 100) train acc: 0.498000; val_acc: 0.485000
# (Iteration 42201 / 49000) loss: 1.874801
# (Iteration 42301 / 49000) loss: 1.769431
# (Iteration 42401 / 49000) loss: 1.955937
# (Iteration 42501 / 49000) loss: 1.922064
# (Iteration 42601 / 49000) loss: 1.839923
# (Epoch 87 / 100) train acc: 0.511000; val_acc: 0.497000
# (Iteration 42701 / 49000) loss: 2.018353
# (Iteration 42801 / 49000) loss: 1.841140
# (Iteration 42901 / 49000) loss: 1.902101
# (Iteration 43001 / 49000) loss: 1.779628
# (Iteration 43101 / 49000) loss: 1.882440
# (Epoch 88 / 100) train acc: 0.521000; val_acc: 0.521000
# (Iteration 43201 / 49000) loss: 1.719022
# (Iteration 43301 / 49000) loss: 1.966379
# (Iteration 43401 / 49000) loss: 1.848592
# (Iteration 43501 / 49000) loss: 1.803670
# (Iteration 43601 / 49000) loss: 1.938195
# (Epoch 89 / 100) train acc: 0.511000; val_acc: 0.507000
# (Iteration 43701 / 49000) loss: 1.777047
# (Iteration 43801 / 49000) loss: 1.898846
# (Iteration 43901 / 49000) loss: 1.655468
# (Iteration 44001 / 49000) loss: 1.934570
# (Epoch 90 / 100) train acc: 0.504000; val_acc: 0.506000
# (Iteration 44101 / 49000) loss: 1.778651
# (Iteration 44201 / 49000) loss: 1.869162
# (Iteration 44301 / 49000) loss: 1.808341
# (Iteration 44401 / 49000) loss: 1.815690
# (Iteration 44501 / 49000) loss: 2.045597
# (Epoch 91 / 100) train acc: 0.509000; val_acc: 0.488000
# (Iteration 44601 / 49000) loss: 1.782735
# (Iteration 44701 / 49000) loss: 2.122864
# (Iteration 44801 / 49000) loss: 1.802701
# (Iteration 44901 / 49000) loss: 1.812909
# (Iteration 45001 / 49000) loss: 1.744082
# (Epoch 92 / 100) train acc: 0.545000; val_acc: 0.511000
# (Iteration 45101 / 49000) loss: 1.936451
# (Iteration 45201 / 49000) loss: 1.905135
# (Iteration 45301 / 49000) loss: 1.871028
# (Iteration 45401 / 49000) loss: 1.796313
# (Iteration 45501 / 49000) loss: 1.808745
# (Epoch 93 / 100) train acc: 0.502000; val_acc: 0.514000
# (Iteration 45601 / 49000) loss: 1.699477
# (Iteration 45701 / 49000) loss: 1.841791
# (Iteration 45801 / 49000) loss: 1.870594
# (Iteration 45901 / 49000) loss: 1.827508
# (Iteration 46001 / 49000) loss: 1.806758
# (Epoch 94 / 100) train acc: 0.514000; val_acc: 0.513000
# (Iteration 46101 / 49000) loss: 2.038590
# (Iteration 46201 / 49000) loss: 2.037512
# (Iteration 46301 / 49000) loss: 1.811673
# (Iteration 46401 / 49000) loss: 1.827610
# (Iteration 46501 / 49000) loss: 1.670911
# (Epoch 95 / 100) train acc: 0.535000; val_acc: 0.508000
# (Iteration 46601 / 49000) loss: 1.864488
# (Iteration 46701 / 49000) loss: 1.737807
# (Iteration 46801 / 49000) loss: 2.005161
# (Iteration 46901 / 49000) loss: 1.747075
# (Iteration 47001 / 49000) loss: 1.673619
# (Epoch 96 / 100) train acc: 0.517000; val_acc: 0.513000
# (Iteration 47101 / 49000) loss: 1.799400
# (Iteration 47201 / 49000) loss: 1.879931
# (Iteration 47301 / 49000) loss: 2.016660
# (Iteration 47401 / 49000) loss: 1.846732
# (Iteration 47501 / 49000) loss: 1.834193
# (Epoch 97 / 100) train acc: 0.523000; val_acc: 0.500000
# (Iteration 47601 / 49000) loss: 1.835951
# (Iteration 47701 / 49000) loss: 1.858155
# (Iteration 47801 / 49000) loss: 2.117845
# (Iteration 47901 / 49000) loss: 1.753807
# (Iteration 48001 / 49000) loss: 1.898679
# (Epoch 98 / 100) train acc: 0.522000; val_acc: 0.505000
# (Iteration 48101 / 49000) loss: 1.742766
# (Iteration 48201 / 49000) loss: 1.937348
# (Iteration 48301 / 49000) loss: 1.778104
# (Iteration 48401 / 49000) loss: 1.847457
# (Iteration 48501 / 49000) loss: 1.697670
# (Epoch 99 / 100) train acc: 0.479000; val_acc: 0.496000
# (Iteration 48601 / 49000) loss: 1.836828
# (Iteration 48701 / 49000) loss: 1.839059
# (Iteration 48801 / 49000) loss: 1.674077
# (Iteration 48901 / 49000) loss: 1.911890
# (Epoch 100 / 100) train acc: 0.533000; val_acc: 0.485000

# %%
y_val_pred = np.argmax(model.loss(data['X_val']), axis=1)
print('Validation set accuracy: {}'.format(np.mean(y_val_pred == data['y_val'])))
# Out:
# Validation set accuracy: 0.527
